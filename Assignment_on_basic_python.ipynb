# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyadarshini-yadav13/Rashmi/blob/main/Assignment_on_basic_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###PYTHON PROGRAMMING BASICS ASSIGNMENT
# Problem Statement:
# This assignment aims to develop foundational skills in Python programming, covering essential concepts like Lists, Tuples, Dictionaries, Sets, Conditional Statements (if-else), Loops (for and while), and loop control statements (break and continue). By completing this assignment, students will gain hands-on experience in basic Python programming constructs necessary for problem-solving and data handling.
# Guidelines:
# 1. Foundational Knowledge:
# Understand the differences between Lists, Tuples, Dictionaries, and Sets.
# Learn how to apply if-else statements for decision-making.
# Use loops effectively for iterating over sequences.
# Understand the role of break and continue in loop control.
# 2. Data Exploration:
# Create and manipulate Lists, Tuples, Dictionaries, and Sets.
# Use indexing and slicing to access elements.
# Perform operations like adding, removing, and updating elements.
# 3. Control Flow and Loops:
# Apply if-else statements to solve logical problems.
# Use for and while loops to iterate through sequences.
# Implement break and continue statements to control loop execution.
# Step-by-Step Approach to Python Programming Basics:
# 1. Setup and Basic Operations:
# Install and set up Python.
# Use print() and input() functions.
# Assign values to variables and explore different data types.
# 2. List Operations:
# Create a list and perform basic operations like append(), remove(), pop(), and slicing.
# Iterate over a list using loops.
#
# 3. Tuple Operations:
# Create and access tuple elements.
# Understand the immutability of tuples.
# Use tuple unpacking.
# 4. Dictionary Operations:
# Create a dictionary with key-value pairs.
# Perform operations like adding, updating, and deleting key-value pairs.
# Iterate through a dictionary using loops.
# 5. Set Operations:
# Create a set and perform operations like union, intersection, and difference.
# Understand the uniqueness property of sets.
# 6. Conditional Statements:
# Implement if-else conditions for decision-making.
# Use nested if-else conditions for complex logic.
# 7. Looping Constructs:
# Use for loops to iterate over lists, tuples, and dictionaries.
# Use while loops for repeating tasks.
# Implement break and continue statements to control loops.
# 8. Problem-Solving Tasks:
# Write a Python program to find the largest number in a list.
# 1-Write a Python program to count the frequency of elements in a list.
# 2-Create a dictionary that stores student names as keys and marks as values, then find the student with the highest marks.
# 3-Implement a while loop to print the Fibonacci series up to a given number.
# 4-Use a set to remove duplicate elements from a list.
# Dataset for Practice:
# While this assignment focuses on Python basics, students can use small sample datasets manually created in dictionaries or lists for practice. Examples:
# A dictionary of student names and marks.
# A list of numbers for performing mathematical operations.

# %%
### Print function
print("i_am_priyadarshini.")
# Out:
# i_am_priyadarshini.

# %% [markdown]
# ### we can use '' also

# %%
print('i_am_priyadarshini.')
# Out:
# i_am_priyadarshini.

# %%
### Input function

# %% [markdown]
# ###input() asks the user to type something and gives you their answer as text.

# %%
age = input("How old are you? ")
print("Next year you'll be", int(age) + 1)
# Out:
# How old are you? 25
# Next year you'll be 26

# %%
standard=input("what is your standard? ")
print("Next year you will be in", int(standard)+1)
# Out:
# what is your standard? 6
# Next year you will be in 7

# %%
##Numeric addition
num1 = float(input("First number: "))
num2 = float(input("Second number: "))
print("Sum:", num1 + num2)
# Out:
# First number: 2
# Second number: 3
# Sum: 5.0

# %% [markdown]
# ... Different data types-float,integer,boolean,string

# %%
## Data type
Name="Priyadarshini"
print(Name)
print(type(Name))
# Out:
# Priyadarshini
# <class 'str'>

# %%
## Data type
speed=40
print(speed)
print(type(speed))
# Out:
# 40
# <class 'int'>

# %%
## Data type
weight=50.8
print(weight)
print(type(weight))
# Out:
# 50.8
# <class 'float'>

# %%
### Datatype
is_spam=True
print(is_spam)
print(type(is_spam))
# Out:
# True
# <class 'bool'>

# %%
### Datatype
is_spam=False
print(is_spam)
print(type(is_spam))
# Out:
# False
# <class 'bool'>

# %% [markdown]
# We always need a "" for string.

# %%
'''
List ->
Heterogenous (Elements of different data types are allowed),
Mutable (Can edit the values),
Allow duplicate values,
Ordered (The sequence in which we give the data, it is preserved)

Lists can be declared with [] or list()
'''
# Out:
# '\nList ->\nHeterogenous (Elements of different data types are allowed),\nMutable (Can edit the values),\nAllow duplicate values,\nOrdered (The sequence in which we give the data, it is preserved)\n\nLists can be declared with [] or list()\n'

# %%
## Creating a list
list=[1,2.5,True,"Priya"]
print(list)
print(type(list))
# Out:
# [1, 2.5, True, 'Priya']
# <class 'list'>

# %% [markdown]
# ## It is Heterogenous (Elements of different data types are allowed)

# %%
## Property no 2-->Mutable (Can edit the values)
list=[1,2.5,True,"Priya"]
print(list)
list[2]=False
print(list)
# Out:
# [1, 2.5, True, 'Priya']
# [1, 2.5, False, 'Priya']

# %%
## Property no 3-->Allow duplicate values
list=[1,2.5,True,"Priya",2.5]
print(list)
# Out:
# [1, 2.5, True, 'Priya', 2.5]

# %%
## Property no 4-->Ordered (The sequence in which we give the data, it is preserved)
list=[1,2.5,True,"Priya"]
print(list)
# Out:
# [1, 2.5, True, 'Priya']

# %%
## indexing
list=[1,2.5,True,"Priya"]
print(list[0])
print(list[3])
# Out:
# 1
# Priya

# %% [markdown]
# ##in python indexing starts from 0..

# %%
## Negative indexing
list=[1,2.5,True,"Priya"]
print(list[-1])
print(list[-4])
# Out:
# Priya
# 1

# %%
## # Slicing -> used to get range of values
list=[1,2.5,True,"Priya"]
print(list[0:3])
# Out:
# [1, 2.5, True]

# %%
'''
ls[start : stop] ->
we extract elements from starting index till stopping index but not stopping index
'''
# Out:
# '\nls[start : stop] ->\nwe extract elements from starting index till stopping index but not stopping index\n'

# %%
list=[1,2.5,True,"Priya"]
print(list[0:2])
# Out:
# [1, 2.5]

# %%
# Element at stopping index is not included

# %%
list=['Priya','Sona','Peehu','Ayraa']
print(list[0:2])
# Out:
# ['Priya', 'Sona']

# %%
list=['Priya','Sona','Peehu','Ayraa']
print(list[-3:-1])
# Out:
# ['Sona', 'Peehu']

# %%
### one possitive and one negative index
list=['Priya','Sona','Peehu','Ayraa']
print(list[-4:2])
# Out:
# ['Priya', 'Sona']

# %%
# append() -> used to insert a single element at the rightmost end
a=[1,2.5,True,"Priya"]
print("Actual list :", a)
a.append('Ayraa')
print("Updated list :", a)
# Out:
# Actual list : [1, 2.5, True, 'Priya']
# Updated list : [1, 2.5, True, 'Priya', 'Ayraa']

# %%
# extend() -> used to insert multiple elements simultaneously at the rightmost end
a=[1,2.5,True,"Priya"]
print("Actual list :", a)
a.extend(['Ayraa','nitya','Anaya'])
print("Updated list :", a)
# Out:
# Actual list : [1, 2.5, True, 'Priya']
# Updated list : [1, 2.5, True, 'Priya', 'Ayraa', 'nitya', 'Anaya']

# %%
# insert(index, element) -> used to insert a single element at a particular position
a=[1,2.5,True,"Priya"]
print("Actual list :", a)
a.insert(2,'Ayraa')
print("Updated list :", a)
# Out:
# Actual list : [1, 2.5, True, 'Priya']
# Updated list : [1, 2.5, 'Ayraa', True, 'Priya']

# %%
# pop() -> used to remove the element at the rightmost end
a = [1, 5.0, True, 'Python']
print('Actual List :', a)
a.pop()
print('Updated List :', a)
# Out:
# Actual List : [1, 5.0, True, 'Python']
# Updated List : [1, 5.0, True]

# %%
# remove() -> removes the first occurence of a particular element
a = [True, 1, 5.0, True, 'Python']
print('Actual List :', a)
a.remove(True)
print('Updated List :', a)
# Out:
# Actual List : [True, 1, 5.0, True, 'Python']
# Updated List : [1, 5.0, True, 'Python']

# %%
##Iterate over a list using loops.
fruits = ['apple', 'banana', 'orange']
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# orange

# %% [markdown]
# A few functions that are used in the list are:
# - append
# - extend
# - remove
# - pop

# %%
'''
Tuples ->
Heterogenous (Elements of different data types are allowed),
Immutable (Cannot edit the values),
Allow duplicate values,
Ordered (The sequence in which we give the data, it is preserved)

Tuples can be declared with () or tuple()
'''
# Out:
# '\nTuples ->\nHeterogenous (Elements of different data types are allowed),\nImmutable (Cannot edit the values),\nAllow duplicate values,\nOrdered (The sequence in which we give the data, it is preserved)\n\nTuples can be declared with () or tuple()\n'

# %%
### Creating tuple
b=(3,3.5,True,"Priya")
print(b)
print(type(b))
# Out:
# (3, 3.5, True, 'Priya')
# <class 'tuple'>

# %%
### Creating tuple
b=(3,3.5,True,"Priya")
print(b)
print(type(b))
# Out:
# (3, 3.5, True, 'Priya')
# <class 'tuple'>

# %%
## Property 1 is satisfied as it contains all dataform.

# %%
## property 2 --> it is immutable.
b=(3,3.5,True,"Priya")
print(b)
b[2]=False
print(b)
# Out:
# (3, 3.5, True, 'Priya')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2169918413.py in <cell line: 0>()
#       2 b=(3,3.5,True,"Priya")
#       3 print(b)
# ----> 4 b[2]=False
#       5 print(b)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## shows it doesnt support editing.

# %%
## property 3 --> it is allow duplicate value.
b=(3,3.5,True,"Priya",3)
print(b)
# Out:
# (3, 3.5, True, 'Priya', 3)

# %%
## property 4--> it reserve the sequence .
b=(3,3.5,True,"Priya")
print(b)
# Out:
# (3, 3.5, True, 'Priya')

# %%
### Indexing
b=(3,3.5,True,"Priya")
print(b[0])
print(b[3])
# Out:
# 3
# Priya

# %%
##negative indexing
b=(3,3.5,True,"Priya")
print(b[-1])
print(b[-4])
# Out:
# Priya
# 3

# %%
### slicing
b=(3,3.5,True,"Priya")
print(b[0:3])
# Out:
# (3, 3.5, True)

# %% [markdown]
# ###Tuple unpacking assigns tuple elements to variables using commas,matching the number and order of items for clean, readable code.

# %%
###Basic Unpacking-Match variables exactly to tuple length.
point = (10, 20)
x, y = point
print(x, y)
# Out:
# 10 20

# %%
## More example
a=(1,2,3)
x,y,z=a
print(x,y,z)
# Out:
# 1 2 3

# %%
'''
Sets ->
Heterogenous (Elements of different data types are allowed),
Mutable (Can edit the values),
Do not allow duplicate values,
Unordered (The sequence in which we give the data, it is not preserved)

Sets can be declared with {} or set()
Set itself: Mutable (can modify contents).

Elements inside: Must be immutable (cannot modify).
'''
# Out:
# '\nSets ->\nHeterogenous (Elements of different data types are allowed),\nMutable (Can edit the values),\nDo not allow duplicate values,\nUnordered (The sequence in which we give the data, it is not preserved)\n\nSets can be declared with {} or set()\nSet itself: Mutable (can modify contents).\n\nElements inside: Must be immutable (cannot modify).\n'

# %%
### Creating set
S={4,5.6,True,'Ayraa'}
print(S)
print(type(S))
# Out:
# {True, 4, 5.6, 'Ayraa'}
# <class 'set'>

# %%
### Creating set
S={4,5.6,True,'Ayraa'}
print(S)
print(type(S))
# Out:
# {True, 4, 5.6, 'Ayraa'}
# <class 'set'>

# %%
## Property 1 is satisfied as it contains all dataform.

# %%
## Property 2 mutable
S={4,5.6,True,'Ayraa'}
print(S)
S[2]=False
print(S)
# Out:
# {True, 4, 5.6, 'Ayraa'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3961649051.py in <cell line: 0>()
#       2 S={4,5.6,True,'Ayraa'}
#       3 print(S)
# ----> 4 S[2]=False
#       5 print(S)
#
# TypeError: 'set' object does not support item assignment

# %%
## Elements inside: Must be immutable (cannot modify).

# %%
### property 3 ---> does allow duplicate value
S={4,5.6,True,'Ayraa',4}
print(S)
# Out:
# {True, 4, 5.6, 'Ayraa'}

# %%
## does not allow duplicate value.

# %%
### Property 4-->order
S={4,5.6,True,'Ayraa'}
print(S)
# Out:
# {True, 4, 5.6, 'Ayraa'}

# %%
## Sets doesnt preserve the order.

# %% [markdown]
# Few functions which are used for a set are:
# - Add
# - Update
# - Remove
# - Pop
# - Clear

# %%
### indexing
S={4,5.6,True,'Ayraa'}
print(S[0])
print(S[3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1498001033.py in <cell line: 0>()
#       1 ### indexing
#       2 S={4,5.6,True,'Ayraa'}
# ----> 3 print(S[0])
#       4 print(S[3])
#
# TypeError: 'set' object is not subscriptable

# %%
##union, intersection, and difference.

# %%
##Union (| or union())
##Combines all unique elements from two sets.
set1={1,2,3}
set2={3,4,5}
all_set=set1|set2
print(all_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
##Union (| or union())
##Combines all unique elements from two sets.
set1={1,2,3}
set2={3,4,5}
all_set=set1.union(set2)
print(all_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
##Intersection (& or intersection())
##Returns only shared elements
set1={1,2,3}
set2={3,4,5}
common_set=set1&set2
print(common_set)
# Out:
# {3}

# %%
##Intersection (& or intersection())
##Returns only shared elements
set1={1,2,3}
set2={3,4,5}
common_set=set1.intersection(set2)
print(common_set)
# Out:
# {3}

# %%
### Difference (- or difference())
##Elements in first set but not second.
set1={1,2,3}
set2={3,4,5}
diff_set=set1-set2
print(diff_set)
# Out:
# {1, 2}

# %%
### Difference (- or difference())
##Elements in first set but not second.
set1={1,2,3}
set2={3,4,5}
diff_set=set1.difference(set2)
print(diff_set)
# Out:
# {1, 2}

# %%
# add() -> used to add a single element in the set
s={4,5.6,True,'Ayraa'}
print("Actual set :", s)
s.add('Priya')
print("Updated set :", s)
# Out:
# Actual set : {True, 4, 5.6, 'Ayraa'}
# Updated set : {True, 'Priya', 4, 5.6, 'Ayraa'}

# %%
#Update --> used to add more elements in the set.
s={4,5.6,True,'Ayraa'}
print("Actual set :", s)
s.update(['Priya','Sona','Peehu'])
print("Updated set :", s)
# Out:
# Actual set : {True, 4, 5.6, 'Ayraa'}
# Updated set : {True, 'Priya', 4, 5.6, 'Ayraa', 'Sona', 'Peehu'}

# %%
#Remove --> used to remove a specific.
s={4,5.6,True,'Ayraa'}
print("Actual set :", s)
s.remove('Ayraa')
print("Updated set :", s)
# Out:
# Actual set : {True, 4, 5.6, 'Ayraa'}
# Updated set : {True, 4, 5.6}

# %%
#POP --> used to remove an arbitrary element. We are not sure about that.
s={4,5.6,True,'Ayraa'}
print("Actual set :", s)
s.pop()
print("Updated set :", s)
# Out:
# Actual set : {True, 4, 5.6, 'Ayraa'}
# Updated set : {4, 5.6, 'Ayraa'}

# %%
#POP --> used to remove an arbitrary element. We are not sure about that.
s={4,5.6,True,'Ayraa'}
print("Actual set :", s)
s.pop()
print("Updated set :", s)
# Out:
# Actual set : {True, 4, 5.6, 'Ayraa'}
# Updated set : {4, 5.6, 'Ayraa'}

# %%
# clear() -> used to remove all the elements from the set
s={4,5.6,True,'Ayraa'}
print("Actual set :", s)
s.clear()
print("Updated set :", s)
# Out:
# Actual set : {True, 4, 5.6, 'Ayraa'}
# Updated set : set()

# %%
'''
Dictionaries ->
{key : value} mapping pair
Heterogenous (Elements of different data types are allowed),
Mutable (Can edit the values),
Do not allow duplicate keys,
Ordered (The sequence in which we give the data, it is not preserved)

Dictionaries can be declared with {} or dict()
'''
# Out:
# '\nDictionaries ->\n{key : value} mapping pair\nHeterogenous (Elements of different data types are allowed),\nMutable (Can edit the values),\nDo not allow duplicate keys,\nOrdered (The sequence in which we give the data, it is not preserved)\n\nDictionaries can be declared with {} or dict()\n'

# %%
### Creating the dictionary
D={
    'Name':['priya','Ayraa'],
    'Age' : [45,12]
}
print(D)
print(type(D))
# Out:
# {'Name': ['priya', 'Ayraa'], 'Age': [45, 12]}
# <class 'dict'>

# %%
## Accessing the key in dictionary
print(D['Name'])
print(D['Age'])
# Out:
# ['priya', 'Ayraa']
# [45, 12]

# %%
## Accessing the key in dictionary
print(D.keys())
# Out:
# dict_keys(['Name', 'Age'])

# %%
# Accessing the key in dictionary
print(D.values())
# Out:
# dict_values([['priya', 'Ayraa'], [45, 12]])

# %%
# Adding a new key
D['Qualification'] = ['M.Tech', 'B.Tech']
print(D)
# Out:
# {'Name': ['priya', 'Ayraa'], 'Age': [45, 12], 'Qualification': ['M.Tech', 'B.Tech']}

# %%
# Updating the values of a existing key
D['Name'] = ['Mrunay', 'Kedar']
print(D)
# Out:
# {'Name': ['Mrunay', 'Kedar'], 'Age': [45, 12], 'Qualification': ['M.Tech', 'B.Tech']}

# %%
# clear() -> removes all the elements from the dictionary
print('Initial Dictionary :\n', D)
D.clear()
print('Final Dictionary :', D)
# Out:
# Initial Dictionary :
#  {'Name': ['Mrunay', 'Kedar'], 'Age': [45, 12], 'Qualification': ['M.Tech', 'B.Tech']}
# Final Dictionary : {}

# %%
# adding the values of a existing key
D={
    'Name':['priya','Ayraa'],
    'Age' : [45,12]
}
print(D)
D['Qualification'] = ['MBA','MCA']
print(D)
# Out:
# {'Name': ['priya', 'Ayraa'], 'Age': [45, 12]}
# {'Name': ['priya', 'Ayraa'], 'Age': [45, 12], 'Qualification': ['MBA', 'MCA']}

# %%
D['Name']=['sona','Ayraa']
print(D)
# Out:
# {'Name': ['sona', 'Ayraa'], 'Age': [45, 12], 'Qualification': ['MBA', 'MCA']}

# %%
D['Name']=['sona']
print(D)
# Out:
# {'Name': ['sona'], 'Age': [45, 12], 'Qualification': ['MBA', 'MCA']}

# %%
###Iterate through a dictionary using loops.
# Keys only
my_dict = {'apple': 1, 'banana': 2, 'orange': 3}
for key in my_dict:
    print(key)
# Out:
# apple
# banana
# orange

# %%
## Values only
for value in my_dict.values():
    print(value)
# Out:
# 1
# 2
# 3

# %%
## Keys and Values
for key, value in my_dict.items():
    print(key, value)
# Out:
# apple 1
# banana 2
# orange 3

# %%
## conditional statement-->ifelse
def odd_or_even_number(n):
  if n%2==0:
  	print('n is a even number')
  else:
  	print('n is a odd number')

# %%
## driver code
odd_or_even_number(10)
# Out:
# n is a even number

# %%
## driver code
odd_or_even_number(15)
# Out:
# n is a odd number

# %%
### conditional statement if else elif
a=5
if a>0:
  print('a  is positive integer')
elif a<0:
  print('a is negative integer')
else:
  print('a is equal to zero')
# Out:
# a  is positive integer

# %%
### conditional statement if else elif
a=-15
if a>0:
  print('a  is positive integer')
elif a<0:
  print('a is negative integer')
else:
  print('a is equal to zero')
# Out:
# a is negative integer

# %%
##nested ifelse statement
score = 85
if score >= 90:
    print("A")
elif score >= 80:
    if score >= 85:
        print("A-")
    else:
        print("B+")
elif score >= 70:
    print("B")
else:
    print("Below B")
# Out:
# A-

# %%
## While loop
count = 0
while count < 5:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
## break and while loop
num = 0
while num < 10:
    num += 1
    if num == 5:
        break  # Exit loop
    if num % 2 == 0:
        continue  # Skip even numbers
    print(num)
# Out:
# 1
# 3

# %%
'''
i -> iterator (temporary placeholder / variable) which loops through
all the values in the iteratable (which is list 'fruits' in this case)

In the first iteration -> i = 'apple'
In the second iteration -> i = 'banana'
In the third iteration -> i = 'cherry'
'''
# Out:
# "\ni -> iterator (temporary placeholder / variable) which loops through\nall the values in the iteratable (which is list 'fruits' in this case)\n\nIn the first iteration -> i = 'apple'\nIn the second iteration -> i = 'banana'\nIn the third iteration -> i = 'cherry'\n"

# %%
# Example ->
fruits = ['apple', 'banana', 'cherry']
for i in fruits:
    print(i)
# Out:
# apple
# banana
# cherry

# %%
'''
i -> iterator (temporary placeholder / variable) which loops through
all the values in the iteratable (which is list 'fruits' in this case)

In the first iteration -> i = 'apple'
In the second iteration -> i = 'banana'
In the third iteration -> i = 'cherry'
'''
# Out:
# "\ni -> iterator (temporary placeholder / variable) which loops through\nall the values in the iteratable (which is list 'fruits' in this case)\n\nIn the first iteration -> i = 'apple'\nIn the second iteration -> i = 'banana'\nIn the third iteration -> i = 'cherry'\n"

# %%
# while() -> used to perform an operation uptill and unless the condition turns out False
i = 1
while i <= 5:
    print(i)
    i = i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
## Question no 1--Write a Python program to find the largest number in a list.
def find_largest(numbers):
    if not numbers:
        return None

    largest = numbers[0]
    for num in numbers[1:]:
        if num > largest:
            largest = num
    return largest

## Driver code
my_list=[5,7,9,13]
result=find_largest(my_list)
print('largest number in list is',result)
# Out:
# largest number in list is 13

# %%
###Write a Python program to count the frequency of elements in a list.
def count_frequency(elements):
    freq = {}
    for item in elements:
        if item in freq:
            freq[item] += 1
        else:
            freq[item] = 1
    return freq

# Test
data = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]
result = count_frequency(data)
print(result)  # {3: 2, 1: 2, 4: 1, 5: 3, 9: 1, 2: 1, 6: 1}
# Out:
# {3: 2, 1: 2, 4: 1, 5: 3, 9: 1, 2: 1, 6: 1}

# %%
###Create a dictionary that stores student names as keys and marks as values,
###then find the student with the highest marks
students = {'Alice': 85, 'Bob': 92, 'Charlie': 78, 'Diana': 96, 'Eve': 88}

top_student = max(students, key=students.get)
print(f"Top student: {top_student} ({students[top_student]} marks)")
# Out:
# Top student: Diana (96 marks)

# %%
##Implement a while loop to print the Fibonacci series up to a given number.
def fibonacci_up_to(limit):
    if limit < 1:
        print("Please enter a number >= 1")
        return

    a, b = 0, 1
    print(f"Fibonacci series up to {limit}:")

    while b <= limit:
        print(a, end=' ')
        a, b = b, a + b  # Tuple unpacking!

    print()  # New line

# Driver cases
fibonacci_up_to(10)
fibonacci_up_to(50)
# Out:
# Fibonacci series up to 10:
# 0 1 1 2 3 5
# Fibonacci series up to 50:
# 0 1 1 2 3 5 8 13 21

# %%
##Use a set to remove duplicate elements from a list.
def remove_duplicates(lst):
    return __builtins__.list(set(lst))
##driver code
lst=[1,2,2,3,4,4,5]
result=remove_duplicates(lst)
print(result)
# Out:
# [1, 2, 3, 4, 5]

# %%
#to calculate the velocity with time and speed
def calculate_velocity(speed,time):
    velocity=speed/time
    print(f"the valocity is {velocity}")

# %%
## Driver code
calculate_velocity(10,2)
# Out:
# the valocity is 5.0

# %%
#find a code for finding the perimeter of triangle
#user defined function
def calculating_perimeter(side1,side2,side3):
    perimeter=(side1+side2+side3)
    return perimeter

# %%
##Driver code
calculating_perimeter(3,4,5)
# Out:
# 12

# %%
#calculating the cube of the number
def calculated_cube(number):
    cube=number**3
    print(f"the cube of {number} is {cube}")

# %%
##Driver code
calculated_cube(5)
# Out:
# the cube of 5 is 125

# %%
#multiplication of two number
num1 = 5
num2 = 7
product = num1 * num2
print(f"Product of {num1} and {num2} is {product}")
# Out:
# Product of 5 and 7 is 35

# %%
def calculate_rectangle_area(length, width):
  area = length * width
  return area

# %%
##Driver code
calculate_rectangle_area(5,7)
# Out:
# 35

# %%
#to convert the 24 hour to 12 hour pattern
def convert_to_12_hour_pattern(n):
    if n>12:
        n=n-12
        print(f"the time in 12 hour pattern is {n}:00 PM")
    else:
        print(f"the time in 12 hour pattern is {n}:00 AM")

# %%
##Driver code
convert_to_12_hour_pattern(13)
# Out:
# the time in 12 hour pattern is 1:00 PM

# %%
import math

# %%
math.sqrt(36)
# Out:
# 6.0

# %%
math.ceil(5.9)
# Out:
# 6

# %%
math.floor(2.3)
# Out:
# 2

# %%
abs(-6)
# Out:
# 6

# %% [markdown]
# ### Simple mathmatical operations

# %%
a=59
a+=1
print(a)
# Out:
# 60

# %%
b=54
b-=4
print(b)
# Out:
# 50

# %%
c=7
c*=2
print(c)
# Out:
# 14

# %%
d=8
d/=2
print(d)
# Out:
# 4.0

# %%
e=27
f=e%2
print(f)
# Out:
# 1

# %% [markdown]
# ## % gives remainder.

# %%
g=53
g//2
# Out:
# 26

# %% [markdown]
# ## // gives integer value.

# %%
### Regular Division (/)--Always returns a float with decimal places
### Floor Division (//)--Returns the largest integer less than or equal to the result (drops decimal).

# %%
h=5
h=h**2
print(h)
# Out:
# 25

# %% [markdown]
# ### Boolean operators

# %% [markdown]
# #### For "and" Operator
#
# 1.    print(True and True)   # Output: True
# 2.    print(True and False)  # Output: False
# 3.    print(False and True)  # Output: False
# 4.    print(False and False) # Output: False

# %% [markdown]
# #### For "or" operator
#
# 1.    print(True or True)    # Output: True
# 2.    print(True or False)   # Output: True
# 3.    print(False or True)   # Output: True
# 4.    print(False or False)  # Output: False

# %%
def evaluate_eligibility(age, has_degree, experience_years, project_score, is_manager):
  """
      For "and" Operator:
      print(True and True) # Output: True
      print(True and False) # Output: False
      print(False and True) # Output: False
      print(False and False) # Output: False

      For "or" operator:
      print(True or True) # Output: True
      print(True or False) # Output: True
      print(False or True) # Output: True
      print(False or False) # Output: False

      Args:

      Input:
           age: Age of candidate (int type)
           has_degree: Candidate degree if he/she has one (boolean type)
           experience_years: No. of years experience for candidate (int type)
           project_score: Project Score given by ATS system (float type)
           is_manager: Whether the candidate is a manager or not (boolean type)

      Output:
           overall_eligibility: If the candidate is eligible or not (boolean type)

  """

  # Condition 1: Basic requirements
  basic_requirements_met = (age >= 25 and has_degree)

  # Condition 2: Experience or high project score
  experience_or_score = (experience_years >= 5 or project_score > 80)

  # Condition 3: Managerial role with specific age or experience
  manager_specific_criteria = is_manager and (age > 30 or experience_years >= 10)

  # Combine all conditions for overall eligibility
  # A candidate is eligible if they meet basic requirements AND (experience/score OR manager criteria)
  overall_eligibility = basic_requirements_met and (experience_or_score or manager_specific_criteria)

  return overall_eligibility

# Test cases
print(f"Candidate 1 (Eligible): {evaluate_eligibility(28, True, 6, 75, False)}") # True: basic & experience
print(f"Candidate 2 (Eligible): {evaluate_eligibility(26, True, 3, 90, False)}") # True: basic & score
print(f"Candidate 3 (Eligible): {evaluate_eligibility(35, True, 8, 70, True)}") # True: basic & manager criteria (age > 30)
print(f"Candidate 4 (Eligible): {evaluate_eligibility(29, True, 12, 60, True)}") # True: basic & manager criteria (experience >= 10)

print(f"Candidate 5 (Not Eligible): {evaluate_eligibility(22, True, 5, 85, False)}") # False: age < 25 (fails basic)
print(f"Candidate 6 (Not Eligible): {evaluate_eligibility(30, False, 7, 70, False)}") # False: no degree (fails basic)
print(f"Candidate 7 (Not Eligible): {evaluate_eligibility(27, True, 2, 60, False)}") # False: fails experience/score and not manager
print(f"Candidate 8 (Not Eligible): {evaluate_eligibility(29, True, 4, 70, True)}")  # False: manager but fails specific age/experience
# Out:
# Candidate 1 (Eligible): True
# Candidate 2 (Eligible): True
# Candidate 3 (Eligible): True
# Candidate 4 (Eligible): True
# Candidate 5 (Not Eligible): False
# Candidate 6 (Not Eligible): False
# Candidate 7 (Not Eligible): False
# Candidate 8 (Not Eligible): False

# %% [markdown]
# ## Exception Handling

# %% [markdown]
# Exception handling in Python provides a structured way to deal with runtime errors, or "exceptions," that can disrupt the normal flow of a program. Instead of crashing, a program can gracefully handle these unexpected events, allowing for error logging, user feedback, or corrective actions.

# %%
try:
  # Code that might raise an exception
  result = 10 / 0
except ZeroDivisionError:
  # Code to handle ZeroDivisionError
  print("Cannot divide by zero!")
# Out:
# Cannot divide by zero!

# %%
try:
  value = int("abc")
except ValueError:
  print("Invalid input: cannot convert to integer.")
# Out:
# Invalid input: cannot convert to integer.

# %%
try:
  num = int(input("Enter a number: "))
except ValueError:
  print("That's not a valid number!")
else:
  print(f"You entered: {num}")
# Out:
# Enter a number: 1
# You entered: 1

# %%
try:
  file = open("my_file.txt", "r")
  content = file.read()
except FileNotFoundError:
  print("File not found! No such file or directory. Please check the filename or directory name.")
finally:
  if 'file' in locals() and not file.closed:
    print(f"Content in the file: {content}")
    file.close()
    print("File closed.")
# Out:
# File not found! No such file or directory. Please check the filename or directory name.
